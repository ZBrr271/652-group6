# %%
import os
from dotenv import load_dotenv
import pandas as pd
import requests
import time
from itertools import islice
import tqdm
load_dotenv()

API_KEY = os.environ.get('SHIV_LASTFM_API_KEY','f35ca57df799d71fa75bcaeb13322fb6')
BASE_URL = "http://ws.audioscrobbler.com/2.0/"

#https://www.last.fm/api/accounts

# No specific rate limits listed on the website

# %% [markdown]
# #### Table 1 - LasFM Tags / Genres

# %%
tracks_per_tag = 100
max_tags = 10


params = {
    "method": "tag.getTopTags",
    "api_key": API_KEY,
    "format": "json",
}
top_tags_r = requests.get(BASE_URL, params=params)
top_tags_data = top_tags_r.json()
tags_df = pd.DataFrame(top_tags_data['toptags']['tag'][:max_tags])
tags_df.head()

tags_df.to_csv('data/lastfm/tags_df.csv', index=False)
tags_df
# Out:
#                name    count   reach
# 0              rock  4052852  401853
# 1        electronic  2478813  260982
# 2         seen live  2183861   82507
# 3       alternative  2125391  266536
# 4               pop  2063259  232773
# 5             indie  2059424  259559
# 6  female vocalists  1630754  169029
# 7             metal  1297266  158486
# 8  alternative rock  1219438  169658
# 9              jazz  1189231  149487

# %% [markdown]
# ### Table 2 - Tag Ranks

# %%
top_tags_data
# Out:
# {'toptags': {'@attr': {'offset': 0, 'num_res': 50, 'total': 2859101},
#   'tag': [{'name': 'rock', 'count': 4052832, 'reach': 401850},
#    {'name': 'electronic', 'count': 2478779, 'reach': 260978},
#    {'name': 'seen live', 'count': 2183840, 'reach': 82507},
#    {'name': 'alternative', 'count': 2125379, 'reach': 266533},
#    {'name': 'pop', 'count': 2063224, 'reach': 232772},
#    {'name': 'indie', 'count': 2059407, 'reach': 259559},
#    {'name': 'female vocalists', 'count': 1630723, 'reach': 169029},
#    {'name': 'metal', 'count': 1297241, 'reach': 158484},
#    {'name': 'alternative rock', 'count': 1219424, 'reach': 169658},
#    {'name': 'jazz', 'count': 1189219, 'reach': 149486},
#    {'name': 'classic rock', 'count': 1147216, 'reach': 137051},
#    {'name': 'ambient', 'count': 1114857, 'reach': 149272},
#    {'name': 'experimental', 'count': 1102768, 'reach': 144480},
#    {'name': 'folk', 'count': 951090, 'reach': 150826},
#    {'name': 'indie rock', 'count': 919670, 'reach': 136765},
#    {'name': 'punk', 'count': 915426, 'reach': 144961},
#    {'name': 'Hip-Hop', 'count': 910347, 'reach': 130890},
#    {'name': 'hard rock', 'count': 905526, 'reach': 115108},
#    {'name': 'black metal', 'count': 897019, 'reach': 64163},
#    {'name': 'instrumental', 'count': 880156, 'reach': 125714},
#    {'name': 'singer-songwriter', 'count': 852893, 'reach': 109755},
#    {'name': 'dance', 'count': 817280, 'reach': 134083},
#    {'name': '80s', 'count': 794565, 'reach': 100563},
#    {'name': 'death metal', 'count': 754308, 'reach': 72655},
#    {'name': 'Progressive rock', 'count': 749510, 'reach': 96545},
#    {'name': 'heavy metal', 'count': 744863, 'reach': 90688},
#    {'name': 'hardcore', 'count': 718019, 'reach': 99140},
#    {'name': 'british', 'count': 697591, 'reach': 93409},
#    {'name': 'soul', 'count': 691468, 'reach': 101877},
#    {'name': 'chillout', 'count': 651966, 'reach': 103531},
#    {'name': 'electronica', 'count': 637714, 'reach': 102373},
#    {'name': 'rap', 'count': 619850, 'reach': 109921},
#    {'name': 'industrial', 'count': 582602, 'reach': 84816},
#    {'name': 'Classical', 'count': 578080, 'reach': 74761},
#    {'name': 'punk rock', 'count': 577054, 'reach': 98221},
#    {'name': 'Soundtrack', 'count': 572012, 'reach': 85517},
#    {'name': 'blues', 'count': 553727, 'reach': 96297},
#    {'name': 'thrash metal', 'count': 518992, 'reach': 62805},
#    {'name': '90s', 'count': 498084, 'reach': 57072},
#    {'name': 'metalcore', 'count': 494983, 'reach': 68158},
#    {'name': 'psychedelic', 'count': 484836, 'reach': 78489},
#    {'name': 'acoustic', 'count': 483951, 'reach': 111571},
#    {'name': 'japanese', 'count': 476055, 'reach': 50016},
#    {'name': 'hip hop', 'count': 460712, 'reach': 80067},
#    {'name': 'post-rock', 'count': 455082, 'reach': 65965},
#    {'name': 'Progressive metal', 'count': 450658, 'reach': 62735},
#    {'name': 'House', 'count': 447186, 'reach': 74587},
#    {'name': 'german', 'count': 443900, 'reach': 59717},
#    {'name': 'techno', 'count': 440520, 'reach': 72182},
#    {'name': 'trance', 'count': 435531, 'reach': 65246}]}}

# %%
tag_names = tags_df['name'].tolist()
all_tracks = []

for tag in tag_names[:1]:   
    tag_tracks = []
    page = 1

    while len(tag_tracks) < tracks_per_tag: 
        params = {
            "method": "tag.getTopTracks",
            "tag": tag,
            "api_key": API_KEY,
            "format": "json",
            "limit": 100,
            "page": page
        }
        response = requests.get(BASE_URL, params=params,headers= {"User-Agent": "JHU-Project/1.0 (spalit2@jh.edu)"})
        tracks_json = response.json()
        
        for track in tracks_json['tracks']['track']:
            track['tag'] = tag
            track['rank'] = int(track['@attr']['rank'])
            track['artist_name'] = track['artist']['name']
            track['artist_mbid'] = track['artist']['mbid']
        
        tag_tracks.extend(tracks_json['tracks']['track'])
        page += 1
        tracks_df = pd.DataFrame(tag_tracks)[['name','mbid','artist_name','artist_mbid','tag','rank']].rename({'mbid':'track_mbid','name':'track_name'},axis=1)
    
    break
        
    # for track in tag_tracks:
    #     track['tag'] = tag 
    
    # all_tracks.extend(tag_tracks)
    # print('Tag: ', tag, 'completed',':',len(tag_tracks))

# %%
page
# Out:
# 2

# %%
tracks_df
# Out:
#                  track_name                            track_mbid  \
# 0   Smells Like Teen Spirit  0ebe2d92-a11d-4b2b-9922-806383074ed7
# 1            Mr. Brightside  37d516ab-d61f-4bcb-9316-7a0b3eb845a8
# 2                     Creep  d11fcceb-dfc5-4d19-b45d-f4e8f6d3eaa6
# 3           Come as You Are  e05035a3-14ac-4f88-a160-0a144530004e
# 4            Feel Good Inc.  5660558a-bfa7-416f-99d9-a34ca0a34515
# ..                      ...                                   ...
# 95                   Song 2  b39b7227-c271-4ab8-912b-cb1fe2fc0e5e
# 96                 Dream On  dec2c739-0853-4283-a85d-f5330e86f62b
# 97       How to Save a Life  5c5cae19-b26c-4542-907a-9c15b51ab6a6
# 98                Starlight  60e94685-0481-4d3d-bd84-11c389d9b2a5
# 99       On Melancholy Hill  842fbdae-8839-46e6-8a02-7f500a2b6597
#
#     artist_name                           artist_mbid   tag  rank
# 0       Nirvana  9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6  rock     1
# 1   The Killers  95e1ead9-4d31-4808-a7ac-32c3614c116b  rock     2
# 2     Radiohead  a74b1b7f-71a5-4011-9441-d0b5e4122711  rock     3
# 3       Nirvana  9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6  rock     4
# 4      Gorillaz  e21857d5-3256-4547-afb3-4b6ded592596  rock     5
# ..          ...                                   ...   ...   ...
# 95         Blur  ba853904-ae25-4ebb-89d6-c44cfbd71bd2  rock    96
# 96    Aerosmith  3d2b98e5-556f-4451-a3ff-c50ea18d57cb  rock    97
# 97     The Fray  2ddd167f-5b8a-4372-b350-6ad50493bac0  rock    98
# 98         Muse  fd857293-5ab8-40de-b29e-55a69d4e4d0f  rock    99
# 99     Gorillaz  e21857d5-3256-4547-afb3-4b6ded592596  rock   100
#
# [100 rows x 6 columns]

# %%
print(f"Getting tracks for tag: {tag}")
params = {
    "method": "tag.getTopTracks",
    "tag": tag,
    "api_key": API_KEY,
    "format": "json",
    "limit": 1000,
}

# call lastfm api
tracks_r = requests.get(BASE_URL, params=params)
tracks_json = tracks_r.json()
# Out:
# Getting tracks for tag: rock

# %%
len(tracks_json['tracks']['track'])
# Out:
# 50

# %%
len(tracks_json['tracks']['track'])
# Out:
# 50

# %%
tracks_df.groupby(['tag','track_name','artist_name'])

# %%
pd.DataFrame(all_tracks)
# Out:
#                             name duration  \
# 0        Smells Like Teen Spirit      301
# 1                 Mr. Brightside      224
# 2                          Creep      239
# 3                Come as You Are      208
# 4                 Feel Good Inc.      221
# ...                          ...      ...
# 9995                  Summertime      695
# 9996  Why Can't We Live Together      327
# 9997                     Calibre        0
# 9998           As the Stars Fall        0
# 9999                  Temptation      217
#
#                                       mbid  \
# 0     0ebe2d92-a11d-4b2b-9922-806383074ed7
# 1     37d516ab-d61f-4bcb-9316-7a0b3eb845a8
# 2     d11fcceb-dfc5-4d19-b45d-f4e8f6d3eaa6
# 3     e05035a3-14ac-4f88-a160-0a144530004e
# 4     5660558a-bfa7-416f-99d9-a34ca0a34515
# ...                                    ...
# 9995  a8661daf-63c6-4ef1-a746-ce162abb11ef
# 9996  f8d77c6f-40dd-48cd-91ea-d06dd9e3e9f1
# 9997
# 9998  81e4a6c6-bc5f-4b62-8ab8-406d5730bec3
# 9999  e015a013-5083-4701-9331-4afbdf9f9ceb
#
#                                                     url  \
# 0     https://www.last.fm/music/Nirvana/_/Smells+Lik...
# 1     https://www.last.fm/music/The+Killers/_/Mr.+Br...
# 2           https://www.last.fm/music/Radiohead/_/Creep
# 3     https://www.last.fm/music/Nirvana/_/Come+as+Yo...
# 4     https://www.last.fm/music/Gorillaz/_/Feel+Good...
# ...                                                 ...
# 9995  https://www.last.fm/music/John+Coltrane/_/Summ...
# 9996  https://www.last.fm/music/Sade/_/Why+Can%27t+W...
# 9997  https://www.last.fm/music/L%C3%B4+Borges/_/Cal...
# 9998  https://www.last.fm/music/The+Cinematic+Orches...
# 9999  https://www.last.fm/music/Diana+Krall/_/Tempta...
#
#                             streamable  \
# 0     {'#text': '0', 'fulltrack': '0'}
# 1     {'#text': '0', 'fulltrack': '0'}
# 2     {'#text': '0', 'fulltrack': '0'}
# 3     {'#text': '0', 'fulltrack': '0'}
# 4     {'#text': '0', 'fulltrack': '0'}
# ...                                ...
# 9995  {'#text': '0', 'fulltrack': '0'}
# 9996  {'#text': '0', 'fulltrack': '0'}
# 9997  {'#text': '0', 'fulltrack': '0'}
# 9998  {'#text': '0', 'fulltrack': '0'}
# 9999  {'#text': '0', 'fulltrack': '0'}
#
#                                                  artist  \
# 0     {'name': 'Nirvana', 'mbid': '9282c8b4-ca0b-4c6...
# 1     {'name': 'The Killers', 'mbid': '95e1ead9-4d31...
# 2     {'name': 'Radiohead', 'mbid': 'a74b1b7f-71a5-4...
# 3     {'name': 'Nirvana', 'mbid': '9282c8b4-ca0b-4c6...
# 4     {'name': 'Gorillaz', 'mbid': 'e21857d5-3256-45...
# ...                                                 ...
# 9995  {'name': 'John Coltrane', 'mbid': 'b625448e-bf...
# 9996  {'name': 'Sade', 'mbid': '67930b3e-e00b-469f-8...
# 9997  {'name': 'Lô Borges', 'mbid': '5bddb0fa-66f7-4...
# 9998  {'name': 'The Cinematic Orchestra', 'mbid': '7...
# 9999  {'name': 'Diana Krall', 'mbid': '67d2cb7a-9ddb...
#
#                                                   image             @attr  \
# 0     [{'#text': 'https://lastfm.freetls.fastly.net/...     {'rank': '1'}
# 1     [{'#text': 'https://lastfm.freetls.fastly.net/...     {'rank': '2'}
# 2     [{'#text': 'https://lastfm.freetls.fastly.net/...     {'rank': '3'}
# 3     [{'#text': 'https://lastfm.freetls.fastly.net/...     {'rank': '4'}
# 4     [{'#text': 'https://lastfm.freetls.fastly.net/...     {'rank': '5'}
# ...                                                 ...               ...
# 9995  [{'#text': 'https://lastfm.freetls.fastly.net/...   {'rank': '996'}
# 9996  [{'#text': 'https://lastfm.freetls.fastly.net/...   {'rank': '997'}
# 9997  [{'#text': 'https://lastfm.freetls.fastly.net/...   {'rank': '998'}
# 9998  [{'#text': 'https://lastfm.freetls.fastly.net/...   {'rank': '999'}
# 9999  [{'#text': 'https://lastfm.freetls.fastly.net/...  {'rank': '1000'}
#
#        tag  rank              artist_name  \
# 0     rock     1                  Nirvana
# 1     rock     2              The Killers
# 2     rock     3                Radiohead
# 3     rock     4                  Nirvana
# 4     rock     5                 Gorillaz
# ...    ...   ...                      ...
# 9995  jazz   996            John Coltrane
# 9996  jazz   997                     Sade
# 9997  jazz   998                Lô Borges
# 9998  jazz   999  The Cinematic Orchestra
# 9999  jazz  1000              Diana Krall
#
#                                artist_mbid
# 0     9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6
# 1     95e1ead9-4d31-4808-a7ac-32c3614c116b
# 2     a74b1b7f-71a5-4011-9441-d0b5e4122711
# 3     9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6
# 4     e21857d5-3256-4547-afb3-4b6ded592596
# ...                                    ...
# 9995  b625448e-bf4a-41c3-a421-72ad46cdb831
# 9996  67930b3e-e00b-469f-8c74-fd69f20522ec
# 9997  5bddb0fa-66f7-47c8-bf00-afecab627d59
# 9998  7c158ea8-c0aa-410e-bdc1-20bba9759577
# 9999  67d2cb7a-9ddb-4a7f-82bf-5a2d1a038e98
#
# [10000 rows x 12 columns]

# %%
tag_rank_df = pd.DataFrame(all_tracks)[['name','mbid','artist_name','artist_mbid','tag','rank']].rename({'mbid':'track_mbid','name':'track_name'},axis=1)
tag_rank_df.to_csv('data/lastfm/tag_rank_df.csv')
tag_rank_df
# Out:
#                       track_name                            track_mbid  \
# 0        Smells Like Teen Spirit  0ebe2d92-a11d-4b2b-9922-806383074ed7
# 1                 Mr. Brightside  37d516ab-d61f-4bcb-9316-7a0b3eb845a8
# 2                          Creep  d11fcceb-dfc5-4d19-b45d-f4e8f6d3eaa6
# 3                Come as You Are  e05035a3-14ac-4f88-a160-0a144530004e
# 4                 Feel Good Inc.  5660558a-bfa7-416f-99d9-a34ca0a34515
# ...                          ...                                   ...
# 9995                  Summertime  a8661daf-63c6-4ef1-a746-ce162abb11ef
# 9996  Why Can't We Live Together  f8d77c6f-40dd-48cd-91ea-d06dd9e3e9f1
# 9997           As the Stars Fall  81e4a6c6-bc5f-4b62-8ab8-406d5730bec3
# 9998                  Temptation  e015a013-5083-4701-9331-4afbdf9f9ceb
# 9999                     Calibre
#
#                   artist_name                           artist_mbid   tag  \
# 0                     Nirvana  9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6  rock
# 1                 The Killers  95e1ead9-4d31-4808-a7ac-32c3614c116b  rock
# 2                   Radiohead  a74b1b7f-71a5-4011-9441-d0b5e4122711  rock
# 3                     Nirvana  9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6  rock
# 4                    Gorillaz  e21857d5-3256-4547-afb3-4b6ded592596  rock
# ...                       ...                                   ...   ...
# 9995            John Coltrane  b625448e-bf4a-41c3-a421-72ad46cdb831  jazz
# 9996                     Sade  67930b3e-e00b-469f-8c74-fd69f20522ec  jazz
# 9997  The Cinematic Orchestra  7c158ea8-c0aa-410e-bdc1-20bba9759577  jazz
# 9998              Diana Krall  67d2cb7a-9ddb-4a7f-82bf-5a2d1a038e98  jazz
# 9999                Lô Borges  5bddb0fa-66f7-47c8-bf00-afecab627d59  jazz
#
#       rank
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 9995   996
# 9996   997
# 9997   998
# 9998   999
# 9999  1000
#
# [10000 rows x 6 columns]

# %%
import pandas as pd

# %%
df = pd.read_csv('data/lastfm/tag_rank_df.csv')

# %%
df[df['rank'] == 1]
# Out:
#       Unnamed: 0               track_name  \
# 0              0  Smells Like Teen Spirit
# 1000        1000           Feel Good Inc.
# 2000        2000                 espresso
# 3000        3000  Smells Like Teen Spirit
# 4000        4000           Feel Good Inc.
# 5000        5000           Mr. Brightside
# 6000        6000               Poker Face
# 7000        7000               In the End
# 8000        8000  Smells Like Teen Spirit
# 9000        9000            Back to Black
#
#                                 track_mbid        artist_name  \
# 0     0ebe2d92-a11d-4b2b-9922-806383074ed7            Nirvana
# 1000  5660558a-bfa7-416f-99d9-a34ca0a34515           Gorillaz
# 2000                                   NaN  Sabrina Carpenter
# 3000  0ebe2d92-a11d-4b2b-9922-806383074ed7            Nirvana
# 4000  5660558a-bfa7-416f-99d9-a34ca0a34515           Gorillaz
# 5000  37d516ab-d61f-4bcb-9316-7a0b3eb845a8        The Killers
# 6000  c50edf48-ac2b-442f-b24f-d2acf775441c          Lady Gaga
# 7000  9d70086c-5d7a-4e7f-b1ed-c53c4b11310f        Linkin Park
# 8000  0ebe2d92-a11d-4b2b-9922-806383074ed7            Nirvana
# 9000  b0adc7a8-0a90-4e09-8839-a66f315234a2      Amy Winehouse
#
#                                artist_mbid               tag  rank
# 0     9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6              rock     1
# 1000  e21857d5-3256-4547-afb3-4b6ded592596        electronic     1
# 2000  1882fe91-cdd9-49c9-9956-8e06a3810bd4         seen live     1
# 3000  9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6       alternative     1
# 4000  e21857d5-3256-4547-afb3-4b6ded592596               pop     1
# 5000  95e1ead9-4d31-4808-a7ac-32c3614c116b             indie     1
# 6000  650e7db6-b795-4eb5-a702-5ea2fc46c848  female vocalists     1
# 7000  f59c5520-5f46-4d2c-b2c4-822eabf53419             metal     1
# 8000  9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6  alternative rock     1
# 9000  dfe9a7c4-8cf2-47f4-9dcb-d233c2b86ec3              jazz     1

# %% [markdown]
# ### Table 3 - Track Info

# %%
mbids = tag_rank_df['track_mbid'].unique()
tracks = []
for mbid in tqdm.tqdm(mbids):
    try:
        params = {
            "method": "track.getInfo",
            "api_key": API_KEY,
            "mbid": mbid,
            "format": "json"
        }
        response = requests.get(BASE_URL, params=params)
        tracks.append(response.json())
    except:
        print('Error: ', mbid)

    
tracks_df = pd.DataFrame([t['track'] for t in tracks])
# Out:
#   0%|          | 0/4508 [00:00<?, ?it/s]
# 0ebe2d92-a11d-4b2b-9922-806383074ed7

# %%
tracks_df.to_csv('data/lastfm/tracks_df.csv', index=False)
tracks_df
# Out:
#                       name                                  mbid  \
# 0               Knocked Up  6956c27e-3c15-494f-bff9-af2241f2506c
# 1         Need You Tonight  aa12dc94-77b1-4e9b-990f-b2bae959f5e0
# 2           Fitter Happier  5838f978-0822-4e28-874f-e1511324ec3a
# 3                    Mercy  e528371a-0544-4328-a51e-8a2427671fcc
# 4     Blue Ridge Mountains  310fa155-f188-46bb-b39a-f5ab8ac048df
# ...                    ...                                   ...
# 4501             This Fire  da22fa3b-ee21-4326-adda-cfb2dabaaecf
# 4502             Forgotten  241e711d-e836-433c-b4bd-b2340f199f7b
# 4503                Shimmy  668b2928-dbc8-401a-9b2d-6fe546dcd441
# 4504               Mermaid  42640092-938d-49b7-a5ff-2a54f3a33175
# 4505                   Lua  7c687434-6784-4679-99a0-52002d028dd1
#
#                                                     url duration  \
# 0     https://www.last.fm/music/Kings+of+Leon/_/Knoc...   430000
# 1     https://www.last.fm/music/INXS/_/Need+You+Tonight   189000
# 2     https://www.last.fm/music/Radiohead/_/Fitter+H...   117000
# 3               https://www.last.fm/music/Duffy/_/Mercy   220000
# 4     https://www.last.fm/music/Fleet+Foxes/_/Blue+R...   200000
# ...                                                 ...      ...
# 4501  https://www.last.fm/music/Franz+Ferdinand/_/Th...   255000
# 4502  https://www.last.fm/music/Linkin+Park/_/Forgotten   194000
# 4503  https://www.last.fm/music/System+of+a+Down/_/S...   111000
# 4504           https://www.last.fm/music/Sade/_/Mermaid   264000
# 4505        https://www.last.fm/music/Bright+Eyes/_/Lua   271000
#
#                             streamable listeners playcount  \
# 0     {'#text': '0', 'fulltrack': '0'}    491594   3039772
# 1     {'#text': '0', 'fulltrack': '0'}    802799   4589591
# 2     {'#text': '0', 'fulltrack': '0'}   1070145   6165992
# 3     {'#text': '0', 'fulltrack': '0'}    980004   5628145
# 4     {'#text': '0', 'fulltrack': '0'}    701071   5366356
# ...                                ...       ...       ...
# 4501  {'#text': '0', 'fulltrack': '0'}    853912   4660231
# 4502  {'#text': '0', 'fulltrack': '0'}    759399   5715870
# 4503  {'#text': '0', 'fulltrack': '0'}    765557   4783874
# 4504  {'#text': '0', 'fulltrack': '0'}    154552    756496
# 4505  {'#text': '0', 'fulltrack': '0'}    633242   5096708
#
#                                                  artist  \
# 0     {'name': 'Kings of Leon', 'mbid': '6ffb8ea9-23...
# 1     {'name': 'INXS', 'mbid': '481bf5f9-2e7c-4c44-b...
# 2     {'name': 'Radiohead', 'mbid': 'a74b1b7f-71a5-4...
# 3     {'name': 'Duffy', 'mbid': 'da4f7583-bb31-49d2-...
# 4     {'name': 'Fleet Foxes', 'mbid': 'fa97dd36-1b82...
# ...                                                 ...
# 4501  {'name': 'Franz Ferdinand', 'mbid': 'aa7a2827-...
# 4502  {'name': 'Linkin Park', 'mbid': 'f59c5520-5f46...
# 4503  {'name': 'System of a Down', 'mbid': 'cc0b7089...
# 4504  {'name': 'Sade', 'mbid': '67930b3e-e00b-469f-8...
# 4505  {'name': 'Bright Eyes', 'mbid': '78f797e3-4913...
#
#                                                   album  \
# 0     {'artist': 'Kings of Leon', 'title': 'Because ...
# 1     {'artist': 'INXS', 'title': 'Kick', 'mbid': '1...
# 2     {'artist': 'Radiohead', 'title': 'OK Computer'...
# 3     {'artist': 'Duffy', 'title': 'Deluxe EP', 'mbi...
# 4     {'artist': 'Fleet Foxes', 'title': 'Fleet Foxe...
# ...                                                 ...
# 4501  {'artist': 'Franz Ferdinand', 'title': 'Franz ...
# 4502  {'artist': 'Linkin Park', 'title': 'Hybrid The...
# 4503  {'artist': 'System of a Down', 'title': 'Great...
# 4504  {'artist': 'Sade', 'title': 'Love Deluxe', 'mb...
# 4505  {'artist': 'Bright Eyes', 'title': 'Lua', 'mbi...
#
#                                                 toptags  \
# 0     {'tag': [{'name': 'rock', 'url': 'https://www....
# 1     {'tag': [{'name': '80s', 'url': 'https://www.l...
# 2     {'tag': [{'name': 'alternative', 'url': 'https...
# 3     {'tag': [{'name': 'soul', 'url': 'https://www....
# 4     {'tag': [{'name': 'folk', 'url': 'https://www....
# ...                                                 ...
# 4501  {'tag': [{'name': 'indie', 'url': 'https://www...
# 4502  {'tag': [{'name': 'Nu Metal', 'url': 'https://...
# 4503  {'tag': [{'name': 'alternative metal', 'url': ...
# 4504  {'tag': [{'name': 'soul', 'url': 'https://www....
# 4505  {'tag': [{'name': 'indie', 'url': 'https://www...
#
#                                                    wiki
# 0     {'published': '13 Jun 2008, 20:12', 'summary':...
# 1     {'published': '31 Jan 2009, 17:14', 'summary':...
# 2     {'published': '31 Mar 2009, 19:12', 'summary':...
# 3     {'published': '08 Nov 2008, 11:10', 'summary':...
# 4                                                   NaN
# ...                                                 ...
# 4501  {'published': '29 Jan 2009, 13:52', 'summary':...
# 4502  {'published': '26 Jun 2024, 10:18', 'summary':...
# 4503                                                NaN
# 4504  {'published': '02 Aug 2024, 17:30', 'summary':...
# 4505  {'published': '01 Oct 2019, 14:13', 'summary':...
#
# [4506 rows x 11 columns]

# %%
import psycopg2
import pandas as pd

conn = psycopg2.connect(
    host="localhost",
    database="group6",
    user="group6",
    password="group6",
    port="5432"
)

cur = conn.cursor()

# %%
MAX_TAGS = 25
TRACKS_PER_TAG = 100
HEADERS = {"User-Agent": "JHU-Project/1.0 (spalit2@jh.edu)"}
api_key = 'f35ca57df799d71fa75bcaeb13322fb6'
base_url = 'http://ws.audioscrobbler.com/2.0/'
# get top tags from db
with conn:
    with conn.cursor() as cur:
       
        cur.execute("SELECT tag_name FROM lastfm_top_tags")
        top_tags = [tag[0] for tag in cur.fetchall()]

        all_tracks_initial = []
        track_data = []

        # get tracks for each tag
        for tag in top_tags:
            print(f"Getting tracks for tag: {tag}")
            tag_tracks = []
            page = 1
            while len(tag_tracks) < TRACKS_PER_TAG:
                time.sleep(0.2)
                params = {
                    "method": "tag.getTopTracks",
                    "tag": tag,
                    "api_key": api_key,
                    "format": "json",
                    "limit": TRACKS_PER_TAG,
                    "page": page
                }

                response = requests.get(base_url, params=params, headers=HEADERS)
                tracks = response.get("tracks", {}).get("track", [])
                if not tracks:
                    break

                for track in tracks:
                    track["tag"] = tag

                tag_tracks.extend(tracks)
                page += 1
            tag_tracks = tag_tracks[:TRACKS_PER_TAG]
            all_tracks_initial.extend(tag_tracks)
# Out:
# Getting tracks for tag: rock
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 33
#      23 params = {
#      24     "method": "tag.getTopTracks",
#      25     "tag": tag,
#    (...)
#      29     "page": page
#      30 }
#      32 response = requests.get(base_url, params=params, headers=HEADERS)
# ---> 33 tracks = response.get("tracks", {}).get("track", [])
#      34 if not tracks:
#      35     break
#
# AttributeError: 'Response' object has no attribute 'get'

# %%
import uuid

# %%
from datetime import datetime, timedelta
import os
import zipfile
import subprocess
import pandas as pd
import uuid




# Retrieves a specific file from kaggle via API
def get_kag_file():

    # User needs to set up account on kaggle and generate API key
    os.environ['KAGGLE_USERNAME'] = 'zmbarrett'
    os.environ['KAGGLE_KEY'] = 'eca1fde2463f087bbeea1ee3b57d4400'

    # Retrieving a specific dataset
    dataset_name = 'elizabethearhart/billboard-hot-1001958-2024'
    zip_file_name = f"{dataset_name.split('/')[-1]}.zip"
    
    # Data is to go into data subdirectory
    data_dir = os.path.join(os.getcwd(), 'data')
    os.makedirs(data_dir, exist_ok=True)

    # Download the dataset by running the kaggle command
    subprocess.run([
        'kaggle', 'datasets', 'download', 
        '-d', dataset_name, 
        '--force', '-p', data_dir])

    # Unzip to data subdirectory
    zip_path = os.path.join(data_dir, zip_file_name)
    try:

        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(data_dir) 
            extracted_files = zip_ref.namelist()

        if extracted_files:
            extracted_file_name = extracted_files[0]
            print(f"Extracted Kaggle file: {extracted_file_name} to data directory")

    except PermissionError:
        print("Error extracting ZIP file: Permission denied")
        print("Close Kaggle data csv if you already have it open in another program")
        return None

    # Extract first file
    extracted_file_name = extracted_files[0] if extracted_files else None
    print(f"Extracted Kaggle file: {extracted_file_name} to data directory")

    # Keep extracted file, delete zip
    os.remove(zip_path)
    print(f"The ZIP file {zip_file_name} has been deleted\n")

    return extracted_file_name


# Processes kaggle file in data directory and returns a dataframe
def process_kag_file(file_name):
    print(f"\nProcessing Kaggle file: {file_name} ...\n"
          "File contains Bilboard Hot 100 chart data from 1958 to 2024\n"
          "It contains - chart_week, title, performer, current_week, last_week, peak_pos, wks_on_chart\n"
          "Duplicate song title, performer pairs will be removed\n")

    data_dir = os.path.join(os.getcwd(), 'data')
    os.makedirs(data_dir, exist_ok=True)
    kaggle_file_path = os.path.join(data_dir, file_name)

    # Read kaggle file from data directory
    df = pd.read_csv(kaggle_file_path, encoding='utf-8')

    # Strip and lowercase string cols
    df['title'] = df['title'].str.strip().str.lower()
    df['performer'] = df['performer'].str.strip().str.lower()

    # Force chart_wk to date for sorting
    df['chart_week'] = pd.to_datetime(df['chart_week'], errors='coerce')

    # Replace empty strings with None
    df.replace('', None, inplace=True)

    df_kaggle = df.copy()

    # Replace some strings to help with matching to Spotify data
    df_kaggle['performer'] = df_kaggle['performer'].str.replace(r' \(featuring ([^)]*)\)', r',\1', regex=True)
    df_kaggle['performer'] = df_kaggle['performer'].str.replace(r' \(feat. ([^)]*)\)', r',\1', regex=True)
    df_kaggle['performer'] = df_kaggle['performer'].str.replace('featuring', ',')
    df_kaggle['performer'] = df_kaggle['performer'].str.replace('feat.', ',')
    df_kaggle['performer'] = df_kaggle['performer'].str.replace('&', 'and')
    df_kaggle['performer'] = df_kaggle['performer'].str.replace(r' ,', r',', regex=True)
    df_kaggle['title'] = df_kaggle['title'].str.replace(r' \(featuring.*$', '', regex=True)

    # Force int columns to numeric, force any NaNs to None
    int_columns = ['current_week', 'last_week', 'peak_pos', 'wks_on_chart']
    for col in int_columns:
        df_kaggle[col] = pd.to_numeric(df_kaggle[col], errors='coerce')
    df_kaggle[int_columns] = df_kaggle[int_columns].where(pd.notnull(df_kaggle[int_columns]), None)

    # Force int columns to Int64 (needed for one column that was being read as float)
    # Replace 0 with None
    for col in int_columns:
        df_kaggle[col] = df_kaggle[col].astype('Int64')
    for col in int_columns:
        df_kaggle[col] = df_kaggle[col].replace(0, None)


    print(f"Number of Kaggle dataset rows before removing duplicates: {len(df_kaggle)}")

    # First, group by performer and title to find first and last chart dates
    date_groups = df_kaggle.groupby(['performer', 'title']).agg({
        'chart_week': ['min', 'max'],  # Get both first and last dates
        'current_week': 'last',  # Keep values from the most recent entry
        'peak_pos': 'min',      # Always keep lowest (best) peak position
        'wks_on_chart': 'max'   # Keep highest weeks on chart value
    })
    
    # Flatten MultiIndex columns
    date_groups.columns = ['wk_first_charted', 'wk_last_charted', 'last_chart_pos', 
                           'peak_chart_pos', 'total_wks_on_chart']
    date_groups = date_groups.reset_index()
    
    # Convert back to the original dataframe format with the additional column
    df_kaggle = date_groups.copy()

    print(f"Number of Kaggle dataset rows after removing duplicates: {len(df_kaggle)}\n")

    # Rename columns
    df_kaggle.rename(columns={'performer': 'artists',
                           'title': 'song_name'}, inplace=True)
    
    # Reorder columns
    df_kaggle = df_kaggle[['artists', 'song_name', 'peak_chart_pos',
                           'last_chart_pos', 'total_wks_on_chart', 
                           'wk_first_charted', 'wk_last_charted']]


    # Write to CSV for record
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    unique_hot100 = f"unique_hot100_{timestamp}.csv"
    kag_file_name = os.path.join(data_dir, unique_hot100)

    df_kaggle.to_csv(kag_file_name, index=False,
                        encoding='utf-8-sig')
    print(f"Kaggle dataset processed and saved to {unique_hot100}\n")

    count = (df_kaggle['peak_chart_pos'] == 1).sum()
    print(f"Processed Kaggle dataset contains {len(df_kaggle)} songs in total and " 
          f"{count} songs that peaked at #1")
    print(f"Dataframe has columns: {', '.join(df_kaggle.columns)}\n")


    # Return the processed dataframe
    return df_kaggle

# %%
kag_name = get_kag_file()
df_kaggle = process_kag_file(kag_name)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/elizabethearhart/billboard-hot-1001958-2024
# License(s): MIT
# Downloading billboard-hot-1001958-2024.zip to /Users/shivpalit/Desktop/JHU/Data Engineering Principles and Practice/652-group6/extras/notebooks/data
#
# Extracted Kaggle file: hot-100-current.csv to data directory
# Extracted Kaggle file: hot-100-current.csv to data directory
# The ZIP file billboard-hot-1001958-2024.zip has been deleted
#
#
# Processing Kaggle file: hot-100-current.csv ...
# File contains Bilboard Hot 100 chart data from 1958 to 2024
# It contains - chart_week, title, performer, current_week, last_week, peak_pos, wks_on_chart
# Duplicate song title, performer pairs will be removed
# 100%|██████████| 3.20M/3.20M [00:00<00:00, 1.85GB/s]
# Number of Kaggle dataset rows before removing duplicates: 343600
# Number of Kaggle dataset rows after removing duplicates: 31337
#
# Kaggle dataset processed and saved to unique_hot100_20250420_163748.csv
#
# Processed Kaggle dataset contains 31337 songs in total and 1173 songs that peaked at #1
# Dataframe has columns: artists, song_name, peak_chart_pos, last_chart_pos, total_wks_on_chart, wk_first_charted, wk_last_charted

# %%
df_kaggle['artists'].str.split(',').str[0]
# Out:
# 0                         "groove" holmes
# 1                         "groove" holmes
# 2                  "little" jimmy dickens
# 3                         "pookie" hudson
# 4                     "weird al" yankovic
#                        ...
# 31332    ¥$: kanye west and ty dolla $ign
# 31333    ¥$: kanye west and ty dolla $ign
# 31334            ¥$: ye and ty dolla $ign
# 31335            ¥$: ye and ty dolla $ign
# 31336            ¥$: ye and ty dolla $ign
# Name: artists, Length: 31337, dtype: object

# %%
import base64
from urllib.parse import urlencode

client_id = 'd2d5bf12b79f4947be8568a2a4105a93'
client_secret = '61ec80164ca14449a0588e4e64330fda'

# Get a Spotify access token
auth_header = base64.b64encode(f"{client_id}:{client_secret}".encode()).decode()
headers = {
    "Authorization": f"Basic {auth_header}",
    "Content-Type": "application/x-www-form-urlencoded",
}
data = {"grant_type": "client_credentials"}

print("Requesting an access token from Spotify")
response = requests.post("https://accounts.spotify.com/api/token", headers=headers, data=data)
if response.status_code == 200:
    token = response.json().get("access_token")
    token_type = response.json().get("token_type")
    expires_in = response.json().get("expires_in")
    print(f"Received a Spotify {token_type} access token that expires in {expires_in} seconds\n")
else:
    print("Error:", response.status_code, response.text)


headers = {"Authorization": f"Bearer {token}"}

# Harcoding good playlists for our purposes
# Need to do dynamically, Spotify seems to rotate playlist IDs
playlist_queries = [
        "Billboard Hot 100: All #1 hit songs 1958-2024",
        "Top 1000 greatest songs of all time",
        "100 Greatest Rock Songs",
        "Top 100 hip hop hits of all time",
        "100 Greatest Pop Songs",
        "Top 100 Most Popular Electronic Songs Of All Time",
        "Top 100 Alternative Rock Songs",
        "Top 100 Jazz Songs",
        "The 100 Greatest Heavy Metal Songs of All Time",
        "100 Best Folk Songs"
    ]

# Dictionary to store playlist information
playlist_info = {}

# Search for each playlist and retrieve its ID
for query in playlist_queries:
    time.sleep(1)
    print(f"Searching for playlist: \"{query}\"...")
    
    # Set up search parameters
    search_url = "https://api.spotify.com/v1/search"
    params = {
        "q": query,
        "type": "playlist",
        "limit": 1
    }
    
    # Make the search request
    response = requests.get(f"{search_url}?{urlencode(params)}", headers=headers)
    print(response.json()['playlists']['items'])
# Out:
# Requesting an access token from Spotify
# Received a Spotify Bearer access token that expires in 3600 seconds
#
# Searching for playlist: "Billboard Hot 100: All #1 hit songs 1958-2024"...
# [{'collaborative': False, 'description': 'A playlist with all number one hit songs on the Billboard Hot 100 list.', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/7c2c13pKxvFDSV4WSyydyg'}, 'href': 'https://api.spotify.com/v1/playlists/7c2c13pKxvFDSV4WSyydyg', 'id': '7c2c13pKxvFDSV4WSyydyg', 'images': [{'height': None, 'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da842e19fe95567ba0f68d46b9b8', 'width': None}], 'name': 'Billboard Hot 100: All #1 hit songs 1958-2024', 'owner': {'display_name': 'Juan Ceñal', 'external_urls': {'spotify': 'https://open.spotify.com/user/ordago13'}, 'href': 'https://api.spotify.com/v1/users/ordago13', 'id': 'ordago13', 'type': 'user', 'uri': 'spotify:user:ordago13'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAACdANyOK3RFPwS0lKyjIIkEdb2BfUQ', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/7c2c13pKxvFDSV4WSyydyg/tracks', 'total': 1153}, 'type': 'playlist', 'uri': 'spotify:playlist:7c2c13pKxvFDSV4WSyydyg'}]
# Searching for playlist: "Top 1000 greatest songs of all time"...
# [{'collaborative': False, 'description': 'Listen to the currently 1000 most popular songs from 1950 to 1999. You can listen to the greatest songs of all time in this playlist. This playlist is listed most popular to least popular song. Weekly updated (Last: 02-09-25). Cover: The Police. Support my band by listening to Revenge!', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/7epfU4cGVZ1xHWQbQJl7km'}, 'href': 'https://api.spotify.com/v1/playlists/7epfU4cGVZ1xHWQbQJl7km', 'id': '7epfU4cGVZ1xHWQbQJl7km', 'images': [{'height': None, 'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84b5ab96e78cfbbeade1df75be', 'width': None}], 'name': 'Top 1000 Greatest Songs of All Time', 'owner': {'display_name': 'Daan van Ginneken', 'external_urls': {'spotify': 'https://open.spotify.com/user/1183089736'}, 'href': 'https://api.spotify.com/v1/users/1183089736', 'id': '1183089736', 'type': 'user', 'uri': 'spotify:user:1183089736'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAABBYMBTCq2E0pv4PF/FCowSl0OSDEy', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/7epfU4cGVZ1xHWQbQJl7km/tracks', 'total': 1002}, 'type': 'playlist', 'uri': 'spotify:playlist:7epfU4cGVZ1xHWQbQJl7km'}]
# Searching for playlist: "100 Greatest Rock Songs"...
# [{'collaborative': False, 'description': 'Top Classic Rock Hits of All Time, top 100 most popular rock songs, best 90s rock, rock greatest hits T100 greatest rock songs, Gym Rock, Rock n Roll Greatest Hits', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/3DYUw0nHB9o8tLZKQup4zp'}, 'href': 'https://api.spotify.com/v1/playlists/3DYUw0nHB9o8tLZKQup4zp', 'id': '3DYUw0nHB9o8tLZKQup4zp', 'images': [{'height': None, 'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da844aae1f6e39fc01a3c5e37fe1', 'width': None}], 'name': 'Classic Rock #1 Hits', 'owner': {'display_name': 'Rockers!', 'external_urls': {'spotify': 'https://open.spotify.com/user/junglenarwal'}, 'href': 'https://api.spotify.com/v1/users/junglenarwal', 'id': 'junglenarwal', 'type': 'user', 'uri': 'spotify:user:junglenarwal'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAAIasEwyyrib5yPexW0OhOcqvp7eRqR', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/3DYUw0nHB9o8tLZKQup4zp/tracks', 'total': 225}, 'type': 'playlist', 'uri': 'spotify:playlist:3DYUw0nHB9o8tLZKQup4zp'}]
# Searching for playlist: "Top 100 hip hop hits of all time"...
# [{'collaborative': False, 'description': '⭐You can also find us with: top hip hop songs - most famous hip hop songs - songs everyone knows - most popular hip hop hits - greatest hip hop songs ever - top 100 hip hop hits of all time - greatest hip hop collection - best hip hop mix - greatest hip hop songs everyone knows - top 100 hip hop hits', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/02okEcUQXHe2sS5ajE9XG0'}, 'href': 'https://api.spotify.com/v1/playlists/02okEcUQXHe2sS5ajE9XG0', 'id': '02okEcUQXHe2sS5ajE9XG0', 'images': [{'height': None, 'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84fe0c80baf05ee1b592dde51d', 'width': None}], 'name': 'Top 100 Hip Hop Hits Of All Time - Greatest Hip Hop Songs Everyone Knows', 'owner': {'display_name': 'Valdiva Tune', 'external_urls': {'spotify': 'https://open.spotify.com/user/316b4f64ay46nb3vgvmu24fcsrxy'}, 'href': 'https://api.spotify.com/v1/users/316b4f64ay46nb3vgvmu24fcsrxy', 'id': '316b4f64ay46nb3vgvmu24fcsrxy', 'type': 'user', 'uri': 'spotify:user:316b4f64ay46nb3vgvmu24fcsrxy'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAAEF0Eiy/uwolh8/jvYqwNULemJ17dS', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/02okEcUQXHe2sS5ajE9XG0/tracks', 'total': 100}, 'type': 'playlist', 'uri': 'spotify:playlist:02okEcUQXHe2sS5ajE9XG0'}]
# Searching for playlist: "100 Greatest Pop Songs"...
# [{'collaborative': False, 'description': 'Top Classic Rock Hits of All Time, top 100 most popular rock songs, best 90s rock, rock greatest hits T100 greatest rock songs, Gym Rock, Rock n Roll Greatest Hits', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/3DYUw0nHB9o8tLZKQup4zp'}, 'href': 'https://api.spotify.com/v1/playlists/3DYUw0nHB9o8tLZKQup4zp', 'id': '3DYUw0nHB9o8tLZKQup4zp', 'images': [{'height': None, 'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da844aae1f6e39fc01a3c5e37fe1', 'width': None}], 'name': 'Classic Rock #1 Hits', 'owner': {'display_name': 'Rockers!', 'external_urls': {'spotify': 'https://open.spotify.com/user/junglenarwal'}, 'href': 'https://api.spotify.com/v1/users/junglenarwal', 'id': 'junglenarwal', 'type': 'user', 'uri': 'spotify:user:junglenarwal'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAAIasEwyyrib5yPexW0OhOcqvp7eRqR', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/3DYUw0nHB9o8tLZKQup4zp/tracks', 'total': 225}, 'type': 'playlist', 'uri': 'spotify:playlist:3DYUw0nHB9o8tLZKQup4zp'}]
# Searching for playlist: "Top 100 Most Popular Electronic Songs Of All Time"...
# [{'collaborative': False, 'description': 'There were some songs I didn&#x27;t like at all, so I changed them to the ones that deserve a place on this list.', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/0Rlh6J7tSGznKm26EZDwmj'}, 'href': 'https://api.spotify.com/v1/playlists/0Rlh6J7tSGznKm26EZDwmj', 'id': '0Rlh6J7tSGznKm26EZDwmj', 'images': [{'height': 640, 'url': 'https://mosaic.scdn.co/640/ab67616d00001e0229409ca87220ac083d04c6feab67616d00001e023fbd1199826e716e8dc978beab67616d00001e02e88bd6d120a57d11cc287b39ab67616d00001e02fbe22d168a743b782a5e856a', 'width': 640}, {'height': 300, 'url': 'https://mosaic.scdn.co/300/ab67616d00001e0229409ca87220ac083d04c6feab67616d00001e023fbd1199826e716e8dc978beab67616d00001e02e88bd6d120a57d11cc287b39ab67616d00001e02fbe22d168a743b782a5e856a', 'width': 300}, {'height': 60, 'url': 'https://mosaic.scdn.co/60/ab67616d00001e0229409ca87220ac083d04c6feab67616d00001e023fbd1199826e716e8dc978beab67616d00001e02e88bd6d120a57d11cc287b39ab67616d00001e02fbe22d168a743b782a5e856a', 'width': 60}], 'name': 'TOP 100 Most Popular Electronic Songs of All Time', 'owner': {'display_name': 'Darkidex', 'external_urls': {'spotify': 'https://open.spotify.com/user/jm5xujoftxlreosj653vwrm2t'}, 'href': 'https://api.spotify.com/v1/users/jm5xujoftxlreosj653vwrm2t', 'id': 'jm5xujoftxlreosj653vwrm2t', 'type': 'user', 'uri': 'spotify:user:jm5xujoftxlreosj653vwrm2t'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAAAb2pL2JEMzN7di6gzyIqTIjqR5NqY', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/0Rlh6J7tSGznKm26EZDwmj/tracks', 'total': 100}, 'type': 'playlist', 'uri': 'spotify:playlist:0Rlh6J7tSGznKm26EZDwmj'}]
# Searching for playlist: "Top 100 Alternative Rock Songs"...
# [{'collaborative': False, 'description': 'The top 100 alternative rock songs on Spotify from 1990-1999.', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/7xY8wHHjF0wxke2dkK3sRc'}, 'href': 'https://api.spotify.com/v1/playlists/7xY8wHHjF0wxke2dkK3sRc', 'id': '7xY8wHHjF0wxke2dkK3sRc', 'images': [{'height': 640, 'url': 'https://mosaic.scdn.co/640/ab67616d00001e02153d79816d853f2694b2cc70ab67616d00001e0294d08ab63e57b0cae74e8595ab67616d00001e02db89b08034de626ebee6823dab67616d00001e02df55e326ed144ab4f5cecf95', 'width': 640}, {'height': 300, 'url': 'https://mosaic.scdn.co/300/ab67616d00001e02153d79816d853f2694b2cc70ab67616d00001e0294d08ab63e57b0cae74e8595ab67616d00001e02db89b08034de626ebee6823dab67616d00001e02df55e326ed144ab4f5cecf95', 'width': 300}, {'height': 60, 'url': 'https://mosaic.scdn.co/60/ab67616d00001e02153d79816d853f2694b2cc70ab67616d00001e0294d08ab63e57b0cae74e8595ab67616d00001e02db89b08034de626ebee6823dab67616d00001e02df55e326ed144ab4f5cecf95', 'width': 60}], 'name': "90's Alternative Rock (Top 100)", 'owner': {'display_name': 'aly.matthews16', 'external_urls': {'spotify': 'https://open.spotify.com/user/tdkqms1h1k98zcv23ug77vcb1'}, 'href': 'https://api.spotify.com/v1/users/tdkqms1h1k98zcv23ug77vcb1', 'id': 'tdkqms1h1k98zcv23ug77vcb1', 'type': 'user', 'uri': 'spotify:user:tdkqms1h1k98zcv23ug77vcb1'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAAXpdmLezNKC2P6O9S/sZHoGoOeXD5z', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/7xY8wHHjF0wxke2dkK3sRc/tracks', 'total': 112}, 'type': 'playlist', 'uri': 'spotify:playlist:7xY8wHHjF0wxke2dkK3sRc'}]
# Searching for playlist: "Top 100 Jazz Songs"...
# [{'collaborative': False, 'description': '🎧 <a href="https://open.spotify.com/user/11173993464/playlists">More Playlists 👉HERE!</a> Visit Our  <a href="https://dearecords.it/jazz-music/">WEBSITE</a> for More Albums. Songs for Sleep, Relaxation, Study, Focus, Concentration, Stress Relief, Yoga, Massage, Meditation, Baby, Relaxing, Learning, ', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/3LJIKHX4Gs8OCoWpaCzzc7'}, 'href': 'https://api.spotify.com/v1/playlists/3LJIKHX4Gs8OCoWpaCzzc7', 'id': '3LJIKHX4Gs8OCoWpaCzzc7', 'images': [{'height': 640, 'url': 'https://mosaic.scdn.co/640/ab67616d00001e020e32df254f1da182512f5a90ab67616d00001e023bc10a91c0e73added42b3e5ab67616d00001e0243a46800f911c086edd8d4abab67616d00001e02bfa6451025c17d290535fb28', 'width': 640}, {'height': 300, 'url': 'https://mosaic.scdn.co/300/ab67616d00001e020e32df254f1da182512f5a90ab67616d00001e023bc10a91c0e73added42b3e5ab67616d00001e0243a46800f911c086edd8d4abab67616d00001e02bfa6451025c17d290535fb28', 'width': 300}, {'height': 60, 'url': 'https://mosaic.scdn.co/60/ab67616d00001e020e32df254f1da182512f5a90ab67616d00001e023bc10a91c0e73added42b3e5ab67616d00001e0243a46800f911c086edd8d4abab67616d00001e02bfa6451025c17d290535fb28', 'width': 60}], 'name': 'Top 100 Best Acoustic Songs Ever !!!', 'owner': {'display_name': 'Dea Records', 'external_urls': {'spotify': 'https://open.spotify.com/user/11173993464'}, 'href': 'https://api.spotify.com/v1/users/11173993464', 'id': '11173993464', 'type': 'user', 'uri': 'spotify:user:11173993464'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAAEnhpWhdl0BQgaI4cf4Ii3FJyvh8LB', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/3LJIKHX4Gs8OCoWpaCzzc7/tracks', 'total': 747}, 'type': 'playlist', 'uri': 'spotify:playlist:3LJIKHX4Gs8OCoWpaCzzc7'}]
# Searching for playlist: "The 100 Greatest Heavy Metal Songs of All Time"...
# [{'collaborative': False, 'description': 'Devil horns up! From Sabbath to Scorpions to Slipknot, from the Sunset Strip to Scandinavia', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/3DO7LtNyc83HgVhscEY2MX'}, 'href': 'https://api.spotify.com/v1/playlists/3DO7LtNyc83HgVhscEY2MX', 'id': '3DO7LtNyc83HgVhscEY2MX', 'images': [{'height': 640, 'url': 'https://mosaic.scdn.co/640/ab67616d00001e02012d727b175d4a91c792fb4cab67616d00001e02be0e5ebab8c61469b1ff9f62ab67616d00001e02cad4832cb7b5844343278daaab67616d00001e02f5ae9e1d9ea1198fab31aba9', 'width': 640}, {'height': 300, 'url': 'https://mosaic.scdn.co/300/ab67616d00001e02012d727b175d4a91c792fb4cab67616d00001e02be0e5ebab8c61469b1ff9f62ab67616d00001e02cad4832cb7b5844343278daaab67616d00001e02f5ae9e1d9ea1198fab31aba9', 'width': 300}, {'height': 60, 'url': 'https://mosaic.scdn.co/60/ab67616d00001e02012d727b175d4a91c792fb4cab67616d00001e02be0e5ebab8c61469b1ff9f62ab67616d00001e02cad4832cb7b5844343278daaab67616d00001e02f5ae9e1d9ea1198fab31aba9', 'width': 60}], 'name': 'The 100 Greatest Heavy Metal Songs of All Time', 'owner': {'display_name': 'Rolling Stone', 'external_urls': {'spotify': 'https://open.spotify.com/user/rsedit'}, 'href': 'https://api.spotify.com/v1/users/rsedit', 'id': 'rsedit', 'type': 'user', 'uri': 'spotify:user:rsedit'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAAAbrhUfxhTq0Vz0RXGSPEBRvGHrXd/', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/3DO7LtNyc83HgVhscEY2MX/tracks', 'total': 100}, 'type': 'playlist', 'uri': 'spotify:playlist:3DO7LtNyc83HgVhscEY2MX'}]
# Searching for playlist: "100 Best Folk Songs"...
# [{'collaborative': False, 'description': '', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/6Q8iZIj2Eac22iTIsg9Mlj'}, 'href': 'https://api.spotify.com/v1/playlists/6Q8iZIj2Eac22iTIsg9Mlj', 'id': '6Q8iZIj2Eac22iTIsg9Mlj', 'images': [{'height': 640, 'url': 'https://mosaic.scdn.co/640/ab67616d00001e026528dcc259ef64aea8630ae3ab67616d00001e027d214af8499aa95ad220f573ab67616d00001e02af8189afb0031f2199e750d3ab67616d00001e02ca57ba316aeb7f493fcd9477', 'width': 640}, {'height': 300, 'url': 'https://mosaic.scdn.co/300/ab67616d00001e026528dcc259ef64aea8630ae3ab67616d00001e027d214af8499aa95ad220f573ab67616d00001e02af8189afb0031f2199e750d3ab67616d00001e02ca57ba316aeb7f493fcd9477', 'width': 300}, {'height': 60, 'url': 'https://mosaic.scdn.co/60/ab67616d00001e026528dcc259ef64aea8630ae3ab67616d00001e027d214af8499aa95ad220f573ab67616d00001e02af8189afb0031f2199e750d3ab67616d00001e02ca57ba316aeb7f493fcd9477', 'width': 60}], 'name': '100 Best Folk Songs', 'owner': {'display_name': 'blondeblueeyes', 'external_urls': {'spotify': 'https://open.spotify.com/user/blondeblueeyes'}, 'href': 'https://api.spotify.com/v1/users/blondeblueeyes', 'id': 'blondeblueeyes', 'type': 'user', 'uri': 'spotify:user:blondeblueeyes'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAAAeuWeSmcll99Acvw37mdiOKqDH/dC', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/6Q8iZIj2Eac22iTIsg9Mlj/tracks', 'total': 100}, 'type': 'playlist', 'uri': 'spotify:playlist:6Q8iZIj2Eac22iTIsg9Mlj'}]

# %%
response.json()
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=1&query=Top%201000%20greatest%20songs%20of%20all%20time&type=playlist',
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?offset=1&limit=1&query=Top%201000%20greatest%20songs%20of%20all%20time&type=playlist',
#   'offset': 0,
#   'previous': None,
#   'total': 806,
#   'items': [{'collaborative': False,
#     'description': 'Listen to the currently 1000 most popular songs from 1950 to 1999. You can listen to the greatest songs of all time in this playlist. This playlist is listed most popular to least popular song. Weekly updated (Last: 02-09-25). Cover: The Police. Support my band by listening to Revenge!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/7epfU4cGVZ1xHWQbQJl7km'},
#     'href': 'https://api.spotify.com/v1/playlists/7epfU4cGVZ1xHWQbQJl7km',
#     'id': '7epfU4cGVZ1xHWQbQJl7km',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84b5ab96e78cfbbeade1df75be',
#       'width': None}],
#     'name': 'Top 1000 Greatest Songs of All Time',
#     'owner': {'display_name': 'Daan van Ginneken',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/1183089736'},
#      'href': 'https://api.spotify.com/v1/users/1183089736',
#      'id': '1183089736',
#      'type': 'user',
#      'uri': 'spotify:user:1183089736'},
#     'primary_color': None,
#     'public': True,
#     'snapshot_id': 'AAABBYMBTCq2E0pv4PF/FCowSl0OSDEy',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/7epfU4cGVZ1xHWQbQJl7km/tracks',
#      'total': 1002},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7epfU4cGVZ1xHWQbQJl7km'}]}}
